# %%
import pandas as pd

# %%
### 링크로 파일 불러오기

file_url="https://bit.ly/ds01-weight-history"

data=pd.read_csv(file_url,index_col="회차")
# 회차를 인덱스로 사용!

data
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
# 파이썬 범용성=패키지
# 판다스: 엑셀의 대체제
# 장점: 대용량 데이터에 최적화(컴퓨터 메모리의 최대치까지)
# 분석 이후의 웹서비스 개발 등의 다음 스텝까지 한번에 가능
# 간단 체계적

#맨위: 칼럼(회차,이름..)
#세로: 로우
#한줄의 로우를 가져오는 정보: 인덱스(0,1,2,3,..)

data.index
#인덱스 호출
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name='회차')

# %%
data.columns
# Out:
# Index(['이름', '측정일', '몸무게', '단위', '담당', '지점'], dtype='object')

# %%
data.shape
#(로우갯수, 컬럼갯수)
# Out:
# (9, 6)

# %%
data.head()
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data.tail()
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data.head(2)
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남
# 2   강성희  2019-01-02  75.7  kg  김지수  강남

# %%
 ### 기본연산

# %%
data["몸무게"].mean()
#몸무게 칼럼의 평균
# Out:
# 75.83333333333333

# %%
data["몸무게"].min()
# Out:
# 75.0

# %%
data["몸무게"].describe()
#통계연산 요약
# Out:
# count     6.000000
# mean     75.833333
# std       0.492612
# min      75.000000
# 25%      75.700000
# 50%      75.850000
# 75%      76.150000
# max      76.400000
# Name: 몸무게, dtype: float64

# %%
ㅊ
#강남구를 강남으로
# Out:
# 회차
# 1     강남
# 2     강남
# 3     강남
# 4    여의도
# 5     강남
# 6    여의도
# 7    여의도
# 8    여의도
# 9    여의도
# Name: 지점, dtype: object

# %%
data["지점"]=data["지점"].replace("강남구","강남")
#원본데이터 수정
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수   강남
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data["몸무게"].fillna(75.8)
#결측치 채워주기
# Out:
# 회차
# 1    76.4
# 2    75.7
# 3    76.0
# 4    75.8
# 5    76.2
# 6    75.7
# 7    75.8
# 8    75.8
# 9    75.0
# Name: 몸무게, dtype: float64

# %%
data["몸무게"]=data["몸무게"].fillna(75.8)

# %%
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04  75.8  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수   강남
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07  75.8  kg  최재우  여의도
# 8   강성희  2019-01-08  75.8  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data["몸무게(prev)"]=data["몸무게"].shift(+1)
data["몸무게(next)"]=data["몸무게"].shift(-1)
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희  2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희  2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희  2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희  2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희  2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희  2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data["측정일"]
# Out:
# 회차
# 1    2019-01-01
# 2    2019-01-02
# 3    2019-01-03
# 4    2019-01-04
# 5    2019-01-05
# 6    2019-01-06
# 7    2019-01-07
# 8    2019-01-08
# 9    2019-01-09
# Name: 측정일, dtype: object

# %%
data["측정일"]=pd.to_datetime(data["측정일"])
#옵젝트타입을 datetime으로하면 연월일로 쪼갤 수 있음
data["측정일"].dt.year
# Out:
# 회차
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# 5    2019
# 6    2019
# 7    2019
# 8    2019
# 9    2019
# Name: 측정일, dtype: int64

# %%
### 행렬검색

# %%
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
# data["칼럼명"]
data["몸무게"]
# Out:
# 회차
# 1    76.4
# 2    75.7
# 3    76.0
# 4    75.8
# 5    76.2
# 6    75.7
# 7    75.8
# 8    75.8
# 9    75.0
# Name: 몸무게, dtype: float64

# %%
data[["이름","측정일","몸무게"]]
#컬럼 여러개
# Out:
#      이름        측정일   몸무게
# 회차
# 1   강성희 2019-01-01  76.4
# 2   강성희 2019-01-02  75.7
# 3   강성희 2019-01-03  76.0
# 4   강성희 2019-01-04  75.8
# 5   강성희 2019-01-05  76.2
# 6   강성희 2019-01-06  75.7
# 7   강성희 2019-01-07  75.8
# 8   강성희 2019-01-08  75.8
# 9   강성희 2019-01-09  75.0

# %%
colums=["이름","측정일","몸무게"]
data[colums]
# Out:
#      이름        측정일   몸무게
# 회차
# 1   강성희 2019-01-01  76.4
# 2   강성희 2019-01-02  75.7
# 3   강성희 2019-01-03  76.0
# 4   강성희 2019-01-04  75.8
# 5   강성희 2019-01-05  76.2
# 6   강성희 2019-01-06  75.7
# 7   강성희 2019-01-07  75.8
# 8   강성희 2019-01-08  75.8
# 9   강성희 2019-01-09  75.0

# %%
#여기서 회차는 컬럼이 아니고 인덱스임
#그래서 data.["회차"]로 호출 불가능
data.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name='회차')

# %%
#로우부르기
data.loc[1]
# Out:
# 이름                           강성희
# 측정일          2019-01-01 00:00:00
# 몸무게                         76.4
# 단위                            kg
# 담당                           김지수
# 지점                            강남
# 몸무게(prev)                    NaN
# 몸무게(next)                   75.7
# Name: 1, dtype: object

# %%
data.loc[[1,2,3]]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8

# %%
session_ids=[1,2,3]
data.loc[session_ids]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8

# %%
data.loc[1:7]
#로우 1부터 7까지 포함
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8

# %%
# %timeit data.loc[1]["이름"]
#비권장: 2번 실행된거라 속도가 느림
# Out:
# 130 µs ± 2.63 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit data.loc[1,"이름"]
#[인덱스, 칼럼명]
# Out:
# 5.78 µs ± 36.6 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
data.loc[[1,2,3],["이름","측정일","몸무게"]]
# Out:
#      이름        측정일   몸무게
# 회차
# 1   강성희 2019-01-01  76.4
# 2   강성희 2019-01-02  75.7
# 3   강성희 2019-01-03  76.0

# %%
columns=["이름","측정일","몸무게"]
data.loc[1:7,columns]
# Out:
#      이름        측정일   몸무게
# 회차
# 1   강성희 2019-01-01  76.4
# 2   강성희 2019-01-02  75.7
# 3   강성희 2019-01-03  76.0
# 4   강성희 2019-01-04  75.8
# 5   강성희 2019-01-05  76.2
# 6   강성희 2019-01-06  75.7
# 7   강성희 2019-01-07  75.8

# %%
data.at[1,"이름"]
#하나의 로우와 하나의 컬럼을 찾을때만 사용
# Out:
# '강성희'

# %%
### 색인

# %%
data["담당"]=="김지수"
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 담당, dtype: bool

# %%
data[data["담당"]=="김지수"]

#true인데이터만 살림
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수  강남       75.8       75.7

# %%
data[data["몸무게"]>75]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0

# %%
data[data["몸무게"]>"75"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-1bb5d7828adc> in <module>
# ----> 1 data[data["몸무게"]>"75"]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     239     elif is_numeric_v_string_like(lvalues, rvalues):
# ...

# %%
data["단위"]=="kg"
# Out:
# 회차
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: 단위, dtype: bool

# %%
a=["최재우","김민철"]
data[data["담당"].isin(a)]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data[data["담당"].str.contains("김")]
#김이라는 문자를 포함하는 로우들
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data[data["몸무게(prev)"].isnull()]
#몸무게(prev)칼럼이 비어있는 로우
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7

# %%
data[data["몸무게(prev)"].notnull()]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data["몸무게"]>75.5
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# Name: 몸무게, dtype: bool

# %%
data["담당"]=="김지수"
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 담당, dtype: bool

# %%
data[data["담당"]=="김지수"]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수  강남       75.8       75.7

# %%
(data["몸무게"]>75.5)& (data["담당"]=="김지수")
#파이썬 and와 판다스 &의 차이
# 파이썬 or 판다스 |
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data[(data["몸무게"]>75.5)& (data["담당"]=="김지수")]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수  강남       75.8       75.7

# %%
high=(data["몸무게"]>75.5)
kim=(data["담당"]=="김지수")
data[high&kim]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수  강남       75.8       75.7

# %%
data.loc[data["담당"]=="김지수","몸무게"]
#김지수인 것을 찾아낸 다음 몸무게만 !!!출력
# Out:
# 회차
# 1    76.4
# 2    75.7
# 3    76.0
# 5    76.2
# Name: 몸무게, dtype: float64

# %%
data.loc[data["담당"]=="김지수",["몸무게","이름","측정일"]]
#김지수인 것 중에서 몸무게 이름 측정일을 출력
# Out:
#      몸무게   이름        측정일
# 회차
# 1   76.4  강성희 2019-01-01
# 2   75.7  강성희 2019-01-02
# 3   76.0  강성희 2019-01-03
# 5   76.2  강성희 2019-01-05

# %%
### pivot table
pd.pivot_table(data,index="담당",values="몸무게")
#세로:인덱스 가로:벨류
#디폴트: 평균 계산
# Out:
#            몸무게
# 담당
# 김민철  75.400000
# 김지수  76.075000
# 최재우  75.766667

# %%
pd.pivot_table(data,index="담당",values="몸무게",aggfunc='sum')
#누적치
# Out:
#        몸무게
# 담당
# 김민철  150.8
# 김지수  304.3
# 최재우  227.3

# %%
pd.pivot_table(data,index="담당",values="몸무게",aggfunc=['mean','sum'])
#그외에 다른 계산도 넣어서 할 수 있음
# Out:
#           mean    sum
#            몸무게    몸무게
# 담당
# 김민철  75.400000  150.8
# 김지수  76.075000  304.3
# 최재우  75.766667  227.3

# %%
### 컬럼 추가 수정

data["지역"]="서울"
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  서울
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  서울
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  서울
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  서울
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  서울
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  서울
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  서울
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  서울
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  서울

# %%
data["지역"]="부산"
#서울을 부산으로 수정

# %%
data["결제"]=[False,True,True,True,True,True,True,True,True,]

# %%
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역    결제
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  부산  True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  부산  True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  부산  True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  부산  True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  부산  True
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  부산  True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  부산  True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  부산  True
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  부산  True

# %%
data["몸무게(gram)"]=data["몸무게"]*1000
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역    결제  \
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  부산  True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  부산  True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  부산  True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  부산  True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  부산  True
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  부산  True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  부산  True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  부산  True
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  부산  True
#
#     몸무게(gram)
# 회차
# 1     76400.0
# 2     75700.0
# 3     76000.0
# 4     75800.0
# 5     76200.0
# 6     75700.0
# 7     75800.0
# 8     75800.0
# 9     75000.0

# %%
data["과체중"]=data["몸무게"]>75.8
#true false 삽입
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역    결제  \
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  부산  True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  부산  True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  부산  True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  부산  True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  부산  True
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  부산  True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  부산  True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  부산  True
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  부산  True
#
#     몸무게(gram)    과체중
# 회차
# 1     76400.0   True
# 2     75700.0  False
# 3     76000.0   True
# 4     75800.0  False
# 5     76200.0   True
# 6     75700.0  False
# 7     75800.0  False
# 8     75800.0  False
# 9     75000.0  False

# %%
data.loc[data["몸무게"]>75.8,"상태"]="과체중"
data.loc[data["몸무게"]<=75.8,"상태"]="정상"
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역    결제  \
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  부산  True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  부산  True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  부산  True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  부산  True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  부산  True
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  부산  True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  부산  True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  부산  True
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  부산  True
#
#     몸무게(gram)    과체중   상태
# 회차
# 1     76400.0   True  과체중
# 2     75700.0  False   정상
# 3     76000.0   True  과체중
# 4     75800.0  False   정상
# 5     76200.0   True  과체중
# 6     75700.0  False   정상
# 7     75800.0  False   정상
# 8     75800.0  False   정상
# ...

# %%
### 칼럼삭제하기

data.drop(1,axis="index")
#로우지우기

data.drop("몸무게",axis="columns")
#칼럼지우기
# Out:
#      이름        측정일  단위   담당   지점  몸무게(prev)  몸무게(next)  지역    결제  몸무게(gram)  \
# 회차
# 1   강성희 2019-01-01  kg  김지수   강남        NaN       75.7  부산  True    76400.0
# 2   강성희 2019-01-02  kg  김지수   강남       76.4       76.0  부산  True    75700.0
# 3   강성희 2019-01-03  kg  김지수   강남       75.7       75.8  부산  True    76000.0
# 4   강성희 2019-01-04  kg  최재우  여의도       76.0       76.2  부산  True    75800.0
# 5   강성희 2019-01-05  kg  김지수   강남       75.8       75.7  부산  True    76200.0
# 6   강성희 2019-01-06  kg  최재우  여의도       76.2       75.8  부산  True    75700.0
# 7   강성희 2019-01-07  kg  최재우  여의도       75.7       75.8  부산  True    75800.0
# 8   강성희 2019-01-08  kg  김민철  여의도       75.8       75.0  부산  True    75800.0
# 9   강성희 2019-01-09  kg  김민철  여의도       75.8        NaN  부산  True    75000.0
#
#       과체중   상태
# 회차
# 1    True  과체중
# 2   False   정상
# 3    True  과체중
# 4   False   정상
# 5    True  과체중
# 6   False   정상
# 7   False   정상
# 8   False   정상
# 9   False   정상

# %%
data=data.drop(["몸무게(next)","몸무게(gram)"],axis="columns")
#원본데이터에 반영하기
data
# Out:
#      이름        측정일  단위   담당   지점  몸무게(prev)  지역    결제    과체중   상태
# 회차
# 1   강성희 2019-01-01  kg  김지수   강남        NaN  부산  True   True  과체중
# 2   강성희 2019-01-02  kg  김지수   강남       76.4  부산  True  False   정상
# 3   강성희 2019-01-03  kg  김지수   강남       75.7  부산  True   True  과체중
# 4   강성희 2019-01-04  kg  최재우  여의도       76.0  부산  True  False   정상
# 5   강성희 2019-01-05  kg  김지수   강남       75.8  부산  True   True  과체중
# 6   강성희 2019-01-06  kg  최재우  여의도       76.2  부산  True  False   정상
# 7   강성희 2019-01-07  kg  최재우  여의도       75.7  부산  True  False   정상
# 8   강성희 2019-01-08  kg  김민철  여의도       75.8  부산  True  False   정상
# 9   강성희 2019-01-09  kg  김민철  여의도       75.8  부산  True  False   정상

# %%
### 데이터시각화
# %matplotlib inline
#화면에 바로 띄어달라는 명령어
import seaborn as sns

# %%
sns.countplot(data=data,x="몸무게(prev)")
# Out:
# <AxesSubplot:xlabel='몸무게(prev)', ylabel='count'>
# C:\Users\parad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\parad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\parad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44172 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\parad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\parad\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
# barplot은 y축지정해줘야함=숫자값
#countplot은 y축 지정 필요없음=데이터 개수

#연속적데이터인 경우에는 barplot사용: 나이,비용
